# %%
import sys
sys.path.insert(0, '/Users/robertyi/repos/dataframe/dato')
from dato import Pipeable

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as skl
from sklearn.linear_model import LogisticRegression

TRAIN_PATH = '../dato/sampledata/kaggle-titanic-train.csv'
TEST_PATH = '../dato/sampledata/kaggle-titanic-test.csv'
df_train = pd.read_csv(TRAIN_PATH)

# %%
from dato import *

# %% [markdown]
# ## Histogram

# %%
df_train.Parch >> Plot(kind='hist')
# Out:
# (array([678., 118.,   0.,  80.,   0.,   5.,   4.,   0.,   5.,   1.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <a list of 10 Patch objects>)

# %%
df_train.Parch >> Hist
# Out:
# (array([678., 118.,   0.,  80.,   0.,   5.,   4.,   0.,   5.,   1.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <a list of 10 Patch objects>)

# %%
df_train >> Hist('Parch')
# Out:
# (array([678., 118.,   0.,  80.,   0.,   5.,   4.,   0.,   5.,   1.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <a list of 10 Patch objects>)

# %%
df_train >> Hist('Parch', col='Sex', hue='Survived')
plt.legend(frameon=False, )

# %% [markdown]
# ## Bar plot

# %%
new_df = df_train >> GroupBy('Survived') >> Mean()

# %%
new_df.plot(kind='bar')

# %%
new_df >> Bar

# %%
new_df >> Bar('Pclass')

# %%
new_df >> Plot('Pclass', kind='bar')

# %%
new_df >> Bar('Pclass', col='SibSp')

# %%
new_df >> Barh

# %%
new_df >> Barh('Parch')

# %%
new_df >> Barh('Parch', col='SibSp')

# %% [markdown]
# ## Line

# %%
df_train >> Plot

# %%
df_train >> Plot('Pclass', 'Age', 'o')

# %% [markdown]
# ## Scatter

# %%
df_train >> Scatter('Parch', 'Age')

# %%
(df_train['Parch'], df_train['Age']) >> Scatter

# %% [markdown]
# ## Box

# %%
df_train['Age'] >> Box
